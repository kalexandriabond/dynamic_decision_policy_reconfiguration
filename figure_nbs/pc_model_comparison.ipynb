# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
import os, glob
import numpy as np
import pandas as pd
import IPython.display as dp


from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
home = os.path.expanduser('~')
figs = 'Dropbox/loki_0.5/figures/model_comparisons/'
fig_path = os.path.join(home,figs)

# %%
posterior_prob_null_v_all_df = pd.read_csv(os.path.join(home, 'Dropbox/loki_0.5/analysis/aggregated_data/pc_postprob_null_m.csv'))

# %%
# load figures in 

# figs to be included
# mean_pc_models_BF01.png
# mean_pc_models_nulladj_BIC.png
# mean_pc_models_postprob.png
# sub_pc_models_BF01.png
# sub_pc_models_nulladj_BIC.png
# sub_pc_models_postprob.png
# sub_pc_models_raw_BIC.png

# %%
dp.display(dp.Image(os.path.join(fig_path, 'sub_pc_models_postprob.png'),width=1000))

# %%
dp.display(dp.Image(os.path.join(fig_path, 'mean_pc_models_postprob.png'),width=1000))

# %%
dp.display(dp.Image(os.path.join(fig_path, 'sub_pc_models_nulladj_BIC.png'),width=1000))

# %%
dp.display(dp.Image(os.path.join(fig_path, 'mean_pc_models_nulladj_BIC.png'),width=1000))

# %%
dp.display(dp.Image(os.path.join(fig_path, 'sub_pc_models_BF01.png'),width=1000))

# %%
dp.display(dp.Image(os.path.join(fig_path, 'mean_pc_models_BF01.png'),width=1000))

# %%
# display table of posterior probabilities of null given k hypotheses (all models)
posterior_prob_null_v_all_df
# Out:
#    posterior_prob_null  subj_id
# 0             0.997384        1
# 1             0.998350        2
# 2             0.998441        3
# 3             0.993830        4

# %%
print('mean p(time_null | data) : ', np.round(posterior_prob_null_v_all_df.posterior_prob_null.mean(),3), '\nstd of p(time_null | data) : ',
      np.round(posterior_prob_null_v_all_df.posterior_prob_null.std(),3))
# Out:
# mean p(time_null | data) :  0.997
# std of p(time_null | data) :  0.002
