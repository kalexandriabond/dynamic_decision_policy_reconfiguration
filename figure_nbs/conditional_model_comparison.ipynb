# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
import os, glob
import numpy as np
import pandas as pd
import IPython.display as dp


from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
home = os.path.expanduser('~')
figs = 'Dropbox/loki_0.5/figures/model_comparisons/'
fig_path = os.path.join(home,figs)

# %%
os.path.join(home, 'Dropbox/loki_0.5/analysis/aggregated_data/conditional_postprob_null_m.csv')
# Out:
# '/Users/67981492/Dropbox/loki_0.5/analysis/aggregated_data/conditional_postprob_null_m.csv'

# %%
posterior_prob_abs_null_v_all_df = pd.read_csv(os.path.join(home, 'Dropbox/loki_0.5/analysis/aggregated_data/cond_postprob_abs_null_m.csv'))
posterior_prob_time_null_v_all_df = pd.read_csv(os.path.join(home, 'Dropbox/loki_0.5/analysis/aggregated_data/cond_postprob_time_null_m.csv'))

# %%
# load figures in 

# figs to be included
# mean_cond_models_BF01.png
# mean_cond_time_null_models_BF01.png

# mean_cond_models_nulladj_BIC.png
# mean_cond_models_postprob.png


# sub_cond_models_BF01.png
# sub_cond_models_nulladj_BIC.png
# sub_cond_models_postprob.png
# sub_cond_models_raw_BIC.png

# %%
dp.display(dp.Image(os.path.join(fig_path, 'sub_cond_models_postprob.png'),width=1000))

# %%
dp.display(dp.Image(os.path.join(fig_path, 'mean_cond_models_postprob.png'),width=1000))

# %%
dp.display(dp.Image(os.path.join(fig_path, 'sub_cond_models_nulladj_BIC.png'),width=1000))

# %%
dp.display(dp.Image(os.path.join(fig_path, 'mean_cond_models_nulladj_BIC.png'),width=1000))

# %%
dp.display(dp.Image(os.path.join(fig_path, 'sub_cond_models_BF01.png'),width=1000))

# %%
dp.display(dp.Image(os.path.join(fig_path, 'mean_cond_models_BF01.png'),width=1000))

# %%
# display table of posterior probabilities of null for all models 
posterior_prob_abs_null_v_all_df
# Out:
#    posterior_prob_abs_null  subj_id
# 0             5.575177e-39        1
# 1             8.317190e-49        2
# 2             6.546503e-51        3
# 3             1.085976e-46        4

# %%
dp.display(dp.Image(os.path.join(fig_path, 'mean_cond_time_null_models_BF01.png'),width=1000))

# %%
posterior_prob_time_null_v_all_df
# Out:
#    posterior_prob_time_null  subj_id
# 0                  0.050822        1
# 1                  0.994964        2
# 2                  0.995144        3
# 3                  0.997799        4
